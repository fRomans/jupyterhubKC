# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
path_to_file = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-rom-fadeev/transaction_data.csv'
df = pd.read_csv(path_to_file, encoding='windows-1251')

# %%
df
# Out:
#                      date                name  transaction
# 0     2020-03-02 00:37:20   Ekaterina_Petrova    cancelled
# 1     2020-03-02 00:59:09      Irina_Fedorova  successfull
# 2     2020-03-02 01:06:14  Ekaterina_Smirnova  successfull
# 3     2020-03-02 00:02:58    Lolita_Polyanova    cancelled
# 4     2020-03-02 00:17:52      Julia_Smirnova    cancelled
# ...                   ...                 ...          ...
# 5310  2020-03-02 00:09:28   Vasilisa_Fedorova  successfull
# 5311  2020-03-02 00:46:31    Vasilisa_Ozerova  successfull
# 5312  2020-03-02 00:16:38      Olga_Polyanova  successfull
# 5313  2020-03-02 00:13:00  Ekaterina_Smirnova  successfull
# 5314  2020-03-02 01:15:45      Irina_Fedorova    cancelled
#
# [5315 rows x 3 columns]

# %%
df.isna().sum()
# Out:
# date           0
# name           0
# transaction    0
# dtype: int64

# %%
df.head(2)
# Out:
#                   date               name  transaction
# 0  2020-03-02 00:37:20  Ekaterina_Petrova    cancelled
# 1  2020-03-02 00:59:09     Irina_Fedorova  successfull

# %%
uniq_val = df.transaction.unique()

# %%
ff = df.groupby('transaction', as_index=False)\
    .agg({'name' : 'count'})\
#     .value_counts()

# %%
ff
# Out:
#    transaction  name
# 0    cancelled  1619
# 1        error     4
# 2  successfull  3692

# %%
sns.barplot(x='transaction', y='name', data=ff)

# %%
disp_df = df.query('transaction == "successfull"')\
    .groupby('name', as_index=False)\
    .agg({'date' : 'count'})\
    .rename(columns={"date": "transaction"})

# %%
disp_df
# Out:
#                    name  transaction
# 0    Ekaterina_Fedorova           72
# 1     Ekaterina_Ivanova           59
# 2     Ekaterina_Lesnova           63
# 3     Ekaterina_Ozerova           72
# 4     Ekaterina_Petrova           68
# 5   Ekaterina_Polyanova           68
# 6    Ekaterina_Smirnova           77
# 7        Irina_Fedorova           62
# 8         Irina_Ivanova           60
# 9         Irina_Lesnova           76
# 10        Irina_Ozerova           76
# 11        Irina_Petrova           66
# 12      Irina_Polyanova           59
# 13       Irina_Smirnova           63
# 14       Julia_Fedorova           67
# 15        Julia_Ivanova           63
# 16        Julia_Lesnova           55
# 17        Julia_Ozerova           60
# 18        Julia_Petrova           74
# 19      Julia_Polyanova           61
# 20       Julia_Smirnova           67
# 21      Lolita_Fedorova           70
# 22       Lolita_Ivanova           76
# 23       Lolita_Lesnova           52
# ...

# %%
# _____________ЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭ___________________________________________

# %%
disp_df.describe()
# Out:
#        transaction
# count    56.000000
# mean     65.928571
# std       7.787769
# min      46.000000
# 25%      61.000000
# 50%      64.000000
# 75%      72.000000
# max      82.000000

# %%
sns.distplot(disp_df.transaction)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# _______________________________++++++++++++++++++++++++++++++++++++++++++++++++++++++____________________________

# %%
df_updated = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-rom-fadeev/transaction_data_updated.csv', encoding='windows-1251')

# %%
df_updated
# Out:
#                      date                name  transaction  minute
# 0     2020-03-02 00:37:20   Ekaterina_Petrova    cancelled      37
# 1     2020-03-02 00:59:09      Irina_Fedorova  successfull      59
# 2     2020-03-02 01:06:14  Ekaterina_Smirnova  successfull       6
# 3     2020-03-02 00:02:58    Lolita_Polyanova    cancelled       2
# 4     2020-03-02 00:17:52      Julia_Smirnova    cancelled      17
# ...                   ...                 ...          ...     ...
# 5310  2020-03-02 00:09:28   Vasilisa_Fedorova  successfull       9
# 5311  2020-03-02 00:46:31    Vasilisa_Ozerova  successfull      46
# 5312  2020-03-02 00:16:38      Olga_Polyanova  successfull      16
# 5313  2020-03-02 00:13:00  Ekaterina_Smirnova  successfull      13
# 5314  2020-03-02 01:15:45      Irina_Fedorova    cancelled      15
#
# [5315 rows x 4 columns]

# %%
user_vs_minute_pivot = df_updated.groupby(['minute', 'name'], as_index=False)\
    .agg({'transaction' : 'count'})\
    .pivot(index='minute', columns='name', values='transaction')\
    .fillna(0)
    
#     .sort_values('minute', ascending = False)

# %%
user_vs_minute_pivot.sum(axis=1)

# %%
# Out:
#                   date               name  transaction  minute
# 0  2020-03-02 00:37:20  Ekaterina_Petrova    cancelled      37
# 1  2020-03-02 00:59:09     Irina_Fedorova  successfull      59

# %%
df_updated['date'] = pd.to_datetime(df_updated['date'])

# %%
df_updated['true_minute'] = df_updated['date'].dt.minute + (df_updated['date'].dt.hour * 60)

# %%
df_updated = df_updated.query('transaction == "successfull"')\
    .groupby('name', as_index=False)\
    .agg({'date' : 'count'})\
    .rename(columns={"date": "transaction"})

# %%
sns.distplot(disp_df.transaction)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_updated.describe()
# Out:
#        transaction
# count    56.000000
# mean     65.928571
# std       7.787769
# min      46.000000
# 25%      61.000000
# 50%      64.000000
# 75%      72.000000
# max      82.000000
